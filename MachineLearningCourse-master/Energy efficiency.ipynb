# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
# %matplotlib inline

# %%
url='https://github.com/chris1610/pbpython/raw/master/data/sales-feb-2014.xlsx'

# %%
In [4]: pd.read_excel(url, parse_dates=True, index_col='date')
# Out:
#                      account number                             name  \
# date
# 2014-02-01 09:04:59          383080                         Will LLC
# 2014-02-01 11:51:46          412290                    Jerde-Hilpert
# 2014-02-01 17:24:32          412290                    Jerde-Hilpert
# 2014-02-01 19:56:48          412290                    Jerde-Hilpert
# 2014-02-02 03:45:20          672390                  Kuhn-Gusikowski
# 2014-02-02 12:45:50          383080                         Will LLC
# 2014-02-02 17:40:58          714466                  Trantow-Barrows
# 2014-02-02 19:58:26          239344                       Stokes LLC
# 2014-02-03 01:28:04          672390                  Kuhn-Gusikowski
# 2014-02-03 11:27:34          307599      Kassulke, Ondricka and Metz
# 2014-02-04 03:53:52          642753                      Pollich LLC
# 2014-02-04 05:19:52          642753                      Pollich LLC
# ...
